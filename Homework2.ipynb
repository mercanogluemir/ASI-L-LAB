# %% [markdown]
# # Homework 2 — Mixing Lesson 3, 4 & 5
#
# This one is harder than Homework 1. It combines **conditionals** (`if`/`elif`/`else`), **`while` loops**, and **`for` loops** — and it expects you to design the algorithm yourself.
#
# Compared to Homework 1, the instructions here are deliberately shorter. You'll be told **what** the result should be, not **how** to get there step by step. That's on purpose — figuring out the steps *is* the exercise. If you get stuck, re-read the relevant lesson notebook, try a small example on paper first, or test your idea on a tiny case before scaling it up.
#
# Rules for every exercise below:
# - Use only what you've learned so far (variables, operators, `if`/`elif`/`else`, `while`, `for`, `range`, string concatenation). No lists, no functions, no slicing — we haven't covered those yet.
# - Store your final answer in the exact variable name(s) given.
# - Run the checker cell below your code — do not edit it. Some exercises use more than one test case on purpose, so a lucky guess won't pass.
#
# Run this cell first:

# %%
def check(condition, ok="Correct! Well done.", no="Incorrect. Check your logic above and try again."):
    if condition:
        print("✅", ok)
    else:
        print("❌", no)

# %% [markdown]
# ---
# ## Exercise 1 — FizzBuzz Report
#
# For every number from 1 to 20:
# - if it's divisible by 3 **and** 5 → the word `FizzBuzz`
# - else if it's divisible by 3 → the word `Fizz`
# - else if it's divisible by 5 → the word `Buzz`
# - otherwise → the number itself, as text
#
# Build a single string variable `fizzbuzz_report` containing all 20 results in order, separated by spaces (or newlines — either is fine).

# %%
# Exercise 1 -- write your code here
fizzbuzz_report = ""



print(fizzbuzz_report)

# %%
check(
    fizzbuzz_report.split() == [
        "1","2","Fizz","4","Buzz","Fizz","7","8","Fizz","Buzz",
        "11","Fizz","13","14","FizzBuzz","16","17","Fizz","19","Buzz"
    ]
)

# %% [markdown]
# ---
# ## Exercise 2 — Digit Sum (any length)
#
# `number = 738295` (given below, don't change it).
#
# Using a `while` loop, compute the sum of all its digits and store it in `digit_sum`. Your solution should work for a number of **any** length, not just this one.

# %%
# Exercise 2 -- write your code here
number = 738295

digit_sum = 0


print(digit_sum)

# %%
check(digit_sum == 34)

# %% [markdown]
# ---
# ## Exercise 3 — Reverse the Digits
#
# `number = 8300` (given below, don't change it).
#
# Using a `while` loop, build the number you get by reversing its digits, and store it in `reversed_number`. Think carefully about what should happen to the zeros at the end.

# %%
# Exercise 3 -- write your code here
number = 8300

reversed_number = 0


print(reversed_number)

# %%
check(reversed_number == 38)

# %% [markdown]
# ---
# ## Exercise 4 — Palindrome Checker
#
# A palindrome is a word that reads the same forwards and backwards (e.g. `"level"`).
#
# `word1 = "deified"` and `word2 = "algorithm"` (given below, don't change them).
#
# For each word, build its reverse using a `for` loop over its characters (no slicing, no built-in reverse — build it yourself, one character at a time). Then decide whether it's a palindrome.
#
# Store the results in `is_palindrome_1` and `is_palindrome_2` (both booleans).

# %%
# Exercise 4 -- write your code here
word1 = "deified"
word2 = "algorithm"

is_palindrome_1 = 
is_palindrome_2 = 

print(is_palindrome_1, is_palindrome_2)

# %%
check(is_palindrome_1 is True and is_palindrome_2 is False)

# %% [markdown]
# ---
# ## Exercise 5 — Greatest Common Divisor
#
# The **greatest common divisor** (GCD) of two numbers is the largest number that divides both of them with no remainder.
#
# `a = 252` and `b = 105` (given below, don't change them).
#
# Write an algorithm using a `while` loop (and no built-in shortcuts) that computes their GCD and stores it in `gcd`. Think about how the remainder of a division could help you shrink the problem each time.

# %%
# Exercise 5 -- write your code here
a = 252
b = 105

gcd = 


print(gcd)

# %%
check(gcd == 21)

# %% [markdown]
# ---
# ## Exercise 6 — Collatz Steps
#
# Pick a starting number. Repeat this rule until you reach `1`:
# - if the current number is even, divide it by 2
# - if it's odd, multiply it by 3 and add 1
#
# `start = 27` (given below, don't change it).
#
# Count how many steps it takes to reach `1`, and store that count in `steps`.

# %%
# Exercise 6 -- write your code here
start = 27

steps = 0


print(steps)

# %%
check(steps == 111)

# %% [markdown]
# ---
# ## Exercise 7 — Final Challenge: Sum of Primes
#
# `N = 30` (given below, don't change it).
#
# Find the sum of every prime number strictly less than `N`, and store it in `sum_of_primes`.
#
# This needs a loop inside a loop: one to walk through the candidate numbers, and one to test whether each candidate is prime.

# %%
# Exercise 7 -- write your code here
N = 30

sum_of_primes = 0


print(sum_of_primes)

# %%
check(sum_of_primes == 129)

# %% [markdown]
# ---
# ## Wrap-up
#
# If all seven checkers print ✅ **Correct!**, you've built seven real algorithms from scratch — FizzBuzz, digit manipulation, number reversal, palindrome detection, GCD, the Collatz sequence, and a nested-loop prime sieve — using nothing but `if`/`elif`/`else`, `while`, and `for`. That's the core toolkit most programming problems are built from. Lists (Lesson 6) will make several of these even more elegant to write.
